# %%
import pandas as pd

# %%
df1 = pd.read_csv('Fifa.csv')

# %%
df2 = pd.read_csv('cleaned_2017-18.csv')

# %%
df1.head()
# Out:
#                  Name Country Position  Age  Overall_Rating  Future Potential  \
# 0  Agostinho Mabululu  Angola       LW   30              68                68
# 1     Mahmoud Gennesh   Egypt       GK   35              67                67
# 2      Sobhi Suleiman   Egypt       GK   28              63                65
# 3        Mahmoud Alaa   Egypt       CB   32              68                68
# 4     Mahmoud Shabana   Egypt       CB   30              66                66
#
#                  Team  Value Per M$  Total_Stats Score
# 0  Ittihad Alexandria          0.65               1660
# 1  Ittihad Alexandria          0.35               1620
# 2  Ittihad Alexandria          0.20               1480
# 3  Ittihad Alexandria          0.50               1695
# 4  Ittihad Alexandria          0.40               1640

# %%
df2.head()
# Out:
#    rk               player       nation pos           squad            comp  \
# 0   1  Patrick van Aanholt  Netherlands  DF  Crystal Palace  Premier League
# 1   2       Rolando Aarons      England  MF   Newcastle Utd  Premier League
# 2   3       Rolando Aarons      England  MF   Hellas Verona         Serie A
# 3   4        Ignazio Abate        Italy  DF           Milan         Serie A
# 4   5      Aymen Abdennour      Tunisia  DF       Marseille         Ligue 1
#
#    age  born  Matches Played  Avg Mins per Match  ...  Total Shots  \
# 0   26  1990              28                2184  ...           33
# 1   21  1995               4                 139  ...            2
# 2   21  1995              11                 517  ...            3
# 3   30  1986              17                1057  ...            4
# 4   27  1989               8                 499  ...            2
#
#    % Shots on target  Shots p 90  Goals per shot  Goals per shot on target  \
# ...

# %% [markdown]
# Data Wrangling Activities

# %% [markdown]
# 1.Merge df1 and df2 with a left join

# %%
df = df1.merge(df2,how = 'left',left_on = 'Name',right_on = 'player')
df
# Out:
#                      Name Country Position  Age  Overall_Rating  \
# 0      Agostinho Mabululu  Angola       LW   30              68
# 1         Mahmoud Gennesh   Egypt       GK   35              67
# 2          Sobhi Suleiman   Egypt       GK   28              63
# 3            Mahmoud Alaa   Egypt       CB   32              68
# 4         Mahmoud Shabana   Egypt       CB   30              66
# ...                   ...     ...      ...  ...             ...
# 19711         Kohei Okuno   Japan      CDM   21              63
# 19712        Riku Danzaki   Japan       RW   22              64
# 19713    Hayato Fukushima   Japan       CB   21              59
# 19714          Ömer Tokaç  Turkey       LW   18              57
# 19715           Ko Sawada   Japan      CAM   28              60
#
#        Future Potential                Team  Value Per M$  Total_Stats Score  \
# 0                    68  Ittihad Alexandria         0.650               1660
# ...

# %%
df.head()
# Out:
#                  Name Country Position  Age  Overall_Rating  Future Potential  \
# 0  Agostinho Mabululu  Angola       LW   30              68                68
# 1     Mahmoud Gennesh   Egypt       GK   35              67                67
# 2      Sobhi Suleiman   Egypt       GK   28              63                65
# 3        Mahmoud Alaa   Egypt       CB   32              68                68
# 4     Mahmoud Shabana   Egypt       CB   30              66                66
#
#                  Team  Value Per M$  Total_Stats Score  rk  ... Total Shots  \
# 0  Ittihad Alexandria          0.65               1660 NaN  ...         NaN
# 1  Ittihad Alexandria          0.35               1620 NaN  ...         NaN
# 2  Ittihad Alexandria          0.20               1480 NaN  ...         NaN
# 3  Ittihad Alexandria          0.50               1695 NaN  ...         NaN
# 4  Ittihad Alexandria          0.40               1640 NaN  ...         NaN
#
# ...

# %%
df.head(1).T
# Out:
#                                              0
# Name                        Agostinho Mabululu
# Country                                 Angola
# Position                                    LW
# Age                                         30
# Overall_Rating                              68
# ...                                        ...
# % Aerial Duels won                         NaN
# Shot creating actions p 90                 NaN
# Goal creating actions p 90                 NaN
# Crosses Stopped                            NaN
# season                                     NaN
#
# [74 rows x 1 columns]

# %% [markdown]
# 2.Are there any mismatch in resulting sum

# %%
df['Name'].isna().any()
# Out:
# np.False_

# %% [markdown]
# 3.How many rows could not be matched

# %%
df['Name'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 4.Extract the name of the palyers that coudnot be matched

# %%
df.loc[df['Name'].isna()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# 7.remove unncessary columns

# %%
df.head()
# Out:
#                  Name Country Position  Age  Overall_Rating  Future Potential  \
# 0  Agostinho Mabululu  Angola       LW   30              68                68
# 1     Mahmoud Gennesh   Egypt       GK   35              67                67
# 2      Sobhi Suleiman   Egypt       GK   28              63                65
# 3        Mahmoud Alaa   Egypt       CB   32              68                68
# 4     Mahmoud Shabana   Egypt       CB   30              66                66
#
#                  Team  Value Per M$  Total_Stats Score  rk  ... Total Shots  \
# 0  Ittihad Alexandria          0.65               1660 NaN  ...         NaN
# 1  Ittihad Alexandria          0.35               1620 NaN  ...         NaN
# 2  Ittihad Alexandria          0.20               1480 NaN  ...         NaN
# 3  Ittihad Alexandria          0.50               1695 NaN  ...         NaN
# 4  Ittihad Alexandria          0.40               1640 NaN  ...         NaN
#
# ...

# %%
columns_to_drop = [
    "% Shots on target",
    "rk",
    "Value Per M$",
    "Shot creating actions p 90"
]
# use drop method

# %%
df.tail()
# Out:
#                    Name Country Position  Age  Overall_Rating  \
# 19711       Kohei Okuno   Japan      CDM   21              63
# 19712      Riku Danzaki   Japan       RW   22              64
# 19713  Hayato Fukushima   Japan       CB   21              59
# 19714        Ömer Tokaç  Turkey       LW   18              57
# 19715         Ko Sawada   Japan      CAM   28              60
#
#        Future Potential             Team  Value Per M$  Total_Stats Score  \
# 19711                71      Gamba Osaka         1.100               1717
# 19712                71       Motherwell         1.200               1607
# 19713                68  Shonan Bellmare         0.475               1347
# 19714                71  Shonan Bellmare         0.220               1481
# 19715                60  Shonan Bellmare         0.250               1636
#
#       player  ... carries penalty area Possessions lost Goals Scored  \
# 19711    NaN  ...                  NaN              NaN          NaN
# ...

# %%
df1.head()
# Out:
#                  Name Country Position  Age  Overall_Rating  Future Potential  \
# 0  Agostinho Mabululu  Angola       LW   30              68                68
# 1     Mahmoud Gennesh   Egypt       GK   35              67                67
# 2      Sobhi Suleiman   Egypt       GK   28              63                65
# 3        Mahmoud Alaa   Egypt       CB   32              68                68
# 4     Mahmoud Shabana   Egypt       CB   30              66                66
#
#                  Team  Value Per M$  Total_Stats Score
# 0  Ittihad Alexandria          0.65               1660
# 1  Ittihad Alexandria          0.35               1620
# 2  Ittihad Alexandria          0.20               1480
# 3  Ittihad Alexandria          0.50               1695
# 4  Ittihad Alexandria          0.40               1640

# %%
df2.head()
# Out:
#    rk               player       nation pos           squad            comp  \
# 0   1  Patrick van Aanholt  Netherlands  DF  Crystal Palace  Premier League
# 1   2       Rolando Aarons      England  MF   Newcastle Utd  Premier League
# 2   3       Rolando Aarons      England  MF   Hellas Verona         Serie A
# 3   4        Ignazio Abate        Italy  DF           Milan         Serie A
# 4   5      Aymen Abdennour      Tunisia  DF       Marseille         Ligue 1
#
#    age  born  Matches Played  Avg Mins per Match  ...  Total Shots  \
# 0   26  1990              28                2184  ...           33
# 1   21  1995               4                 139  ...            2
# 2   21  1995              11                 517  ...            3
# 3   30  1986              17                1057  ...            4
# 4   27  1989               8                 499  ...            2
#
#    % Shots on target  Shots p 90  Goals per shot  Goals per shot on target  \
# ...

# %% [markdown]
# 9.Convert birthday to a DateTime object

# %%
pd.to_datetime(df['born'])
# Out:
# 0       NaT
# 1       NaT
# 2       NaT
# 3       NaT
# 4       NaT
#          ..
# 19711   NaT
# 19712   NaT
# 19713   NaT
# 19714   NaT
# 19715   NaT
# Name: born, Length: 19716, dtype: datetime64[ns]
