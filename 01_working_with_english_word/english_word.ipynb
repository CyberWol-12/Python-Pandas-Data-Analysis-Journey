# %%
import pandas as pd

# %%
#to read csv file
df = pd.read_csv('akkadian_english_dictionary.csv',index_col='word')

# %%
df.head()
# Out:
#                                    translation
# word
# abnu                                     stone
# abnum        stone, rock, (semi)precious stone
# abnum (NA4)                        stone, rock
# abrātum                     populace, humanity
# abrum               pile of brushwood, bonfire

# %% [markdown]
# Activities

# %% [markdown]
# How many element does the dataframe have?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5488 entries, abnu to zūtum
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   translation  5488 non-null   object
# dtypes: object(1)
# memory usage: 85.8+ KB
