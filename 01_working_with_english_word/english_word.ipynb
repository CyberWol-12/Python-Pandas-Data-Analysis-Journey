# %%
import pandas as pd
import seaborn as sns

# %%
#to read csv file
df = pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Activities

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.shape
# Out:
# (800, 12)

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# Distribution of pokemon Types

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df['Type 1'].value_counts().plot(kind='pie',autopct = '%1.1f%%',colormap='tab20c',figsize=(10,8))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Distribution of Pokemon Hp

# %%
df['HP'].plot(kind = 'hist',figsize = (10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['HP'].plot(kind = 'box',vert = False,figsize = (12,4))
# Out:
# <Axes: >

# %% [markdown]
# Distribution of Legendary pokemon

# %%
df['Legendary'].value_counts()
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %%
df['Legendary'].value_counts().plot(kind = 'pie',autopct =' %1.1f%%',colormap='Set3',figsize = (10,4))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Basic Filtering

# %% [markdown]
# lets start with basic activities regarding filtering

# %% [markdown]
# 1.How many Pokemon exits with an Attack value greater than 150

# %%
sns.boxplot(data = df,x = "Attack")
# Out:
# <Axes: xlabel='Attack'>

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %%
df.loc[df['Attack']>150]
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 137  127        PinsirMega Pinsir      Bug    Flying   65     155      120
# 141  130    GyaradosMega Gyarados    Water      Dark   95     155      109
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 268  248  TyranitarMega Tyranitar     Rock      Dark  100     164      150
# 279  257    BlazikenMega Blaziken     Fire  Fighting   80     160       80
# 313  289                  Slaking   Normal       NaN  150     160      100
# 387  354      BanetteMega Banette    Ghost       NaN   64     165       75
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ...

# %% [markdown]
# 2.select all pokemons with speed of 10 0r less

# %%
df.query("Speed <= 10")
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213    Shuckle     Bug   Rock   20      10      230       10      230
# 359  328   Trapinch  Ground    NaN   45     100       45       45       45
# 486  438     Bonsly    Rock    NaN   50      80       95       10       45
# 495  446   Munchlax  Normal    NaN  135      85       40       40       85
# 658  597  Ferroseed   Grass  Steel   44      50       91       24       86
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 359     10           3      False
# 486     10           4      False
# 495      5           4      False
# 658     10           5      False

# %%
df.loc[df['Speed']<=10]
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213    Shuckle     Bug   Rock   20      10      230       10      230
# 359  328   Trapinch  Ground    NaN   45     100       45       45       45
# 486  438     Bonsly    Rock    NaN   50      80       95       10       45
# 495  446   Munchlax  Normal    NaN  135      85       40       40       85
# 658  597  Ferroseed   Grass  Steel   44      50       91       24       86
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 359     10           3      False
# 486     10           4      False
# 495      5           4      False
# 658     10           5      False

# %%
sns.boxplot(data = df, x = 'Speed')
# Out:
# <Axes: xlabel='Speed'>

# %% [markdown]
# 3.How many Pokemon have a sp.Def value of 25 or less

# %%
df.loc[df["Sp. Def"] <= 25].shape
# Out:
# (18, 12)

# %%
df.loc[df['Sp. Def']<=25]
# Out:
#        #                Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 13    10            Caterpie      Bug     NaN   45      30       35       20
# 14    11             Metapod      Bug     NaN   50      20       55       25
# 16    13              Weedle      Bug  Poison   40      35       30       20
# 17    14              Kakuna      Bug  Poison   45      25       50       25
# 44    39          Jigglypuff   Normal   Fairy  115      45       20       45
# 97    90            Shellder    Water     NaN   30      65      100       45
# 106   98              Krabby    Water     NaN   30     105       90       25
# 125  116              Horsea    Water     NaN   30      40       70       70
# 139  129            Magikarp    Water     NaN   20      10       55       15
# 188  174           Igglybuff   Normal   Fairy   90      30       15       40
# 209  194              Wooper    Water  Ground   55      45       45       25
# ...

# %%
df.loc[df["Sp. Def"] <=25].plot(kind = 'hist',figsize = (12,4))
# Out:
# <Axes: ylabel='Frequency'>
