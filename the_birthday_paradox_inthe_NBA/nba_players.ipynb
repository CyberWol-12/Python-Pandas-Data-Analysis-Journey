# %%
import math
import pandas as pd

# %%
df = pd.read_csv('nba_players.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          Player    Ht     Wt     Colleges Pos  Age   Tm   G  GS  \
# 0           0  Alaa Abdelnaby  6-10  240.0         Duke  PF   22  POR  43   0
# 1           1     Danny Ainge   6-4  175.0          BYU  SG   31  POR  80   0
# 2           2     Mark Bryant   6-9  245.0   Seton Hall  PF   25  POR  53   0
# 3           3    Wayne Cooper  6-10  220.0  New Orleans   C   34  POR  67   1
# 4           4    Walter Davis   6-6  193.0          UNC  SG   36  POR  71  14
#
#    ...  Pts Max  Share                    Team   W   L   W/L%   GB   PS/G  \
# 0  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 1  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 2  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 3  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 4  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
#
#     PA/G   SRS
# 0  106.0  8.47
# 1  106.0  8.47
# ...

# %%
df['Team'].value_counts()
# Out:
# Team
# Philadelphia 76ers                   664
# Golden State Warriors                659
# Cleveland Cavaliers                  657
# San Antonio Spurs                    655
# Atlanta Hawks                        653
# Houston Rockets                      652
# Milwaukee Bucks                      648
# Boston Celtics                       643
# New York Knicks                      642
# Denver Nuggets                       635
# Indiana Pacers                       634
# Detroit Pistons                      633
# Chicago Bulls                        625
# Dallas Mavericks                     625
# Los Angeles Lakers                   624
# Phoenix Suns                         622
# Portland Trail Blazers               617
# Los Angeles Clippers                 615
# Utah Jazz                            614
# Sacramento Kings                     542
# Miami Heat                           522
# New Jersey Nets                      508
# Orlando Magic                        493
# ...

# %% [markdown]
# Probability

# %%
def nCr(n,k):
    f = math.factorial
    return f(n)/ (f(k) * f(n - k))

# %%
nCr(12,2)
# Out:
# 495.0

# %%
nCr(2,2)
# Out:
# 1.0

# %%
nCr(3,2)
# Out:
# 3.0

# %% [markdown]
# implementing birthday_probability function

# %%
1 - ((364/365)) ** nCr(10,2)
# Out:
# 0.11614023654879224

# %%
def birthday_probability(number_of_people):
    return 1 - ((314/316))**nCr(number_of_people,2)
birthday_probability(15)
# Out:
# 0.48658403081125223

# %% [markdown]
# NBA BITHDAY PARADOX ANALYSIS

# %%
df = pd.read_csv("nba_players.csv",parse_dates=['Age'])
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_11760\2320261498.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("nba_players.csv",parse_dates=['Age'])

# %%
df.head()
# Out:
#    Unnamed: 0          Player    Ht     Wt     Colleges Pos  Age   Tm   G  GS  \
# 0           0  Alaa Abdelnaby  6-10  240.0         Duke  PF   22  POR  43   0
# 1           1     Danny Ainge   6-4  175.0          BYU  SG   31  POR  80   0
# 2           2     Mark Bryant   6-9  245.0   Seton Hall  PF   25  POR  53   0
# 3           3    Wayne Cooper  6-10  220.0  New Orleans   C   34  POR  67   1
# 4           4    Walter Davis   6-6  193.0          UNC  SG   36  POR  71  14
#
#    ...  Pts Max  Share                    Team   W   L   W/L%   GB   PS/G  \
# 0  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 1  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 2  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 3  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 4  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
#
#     PA/G   SRS
# 0  106.0  8.47
# 1  106.0  8.47
# ...

# %%
df['Team'].value_counts()
# Out:
# Team
# Philadelphia 76ers                   664
# Golden State Warriors                659
# Cleveland Cavaliers                  657
# San Antonio Spurs                    655
# Atlanta Hawks                        653
# Houston Rockets                      652
# Milwaukee Bucks                      648
# Boston Celtics                       643
# New York Knicks                      642
# Denver Nuggets                       635
# Indiana Pacers                       634
# Detroit Pistons                      633
# Chicago Bulls                        625
# Dallas Mavericks                     625
# Los Angeles Lakers                   624
# Phoenix Suns                         622
# Portland Trail Blazers               617
# Los Angeles Clippers                 615
# Utah Jazz                            614
# Sacramento Kings                     542
# Miami Heat                           522
# New Jersey Nets                      508
# Orlando Magic                        493
# ...

# %%
from itertools import combinations

# %%
names = ["John","Mary","Rob","Susan","Violet"]
birthday = ["March 5th","Sept 20th","March 39","July 23","Sept 23"]

# %%
list(combinations(birthday,2))
# Out:
# [('March 5th', 'Sept 20th'),
#  ('March 5th', 'March 39'),
#  ('March 5th', 'July 23'),
#  ('March 5th', 'Sept 23'),
#  ('Sept 20th', 'March 39'),
#  ('Sept 20th', 'July 23'),
#  ('Sept 20th', 'Sept 23'),
#  ('March 39', 'July 23'),
#  ('March 39', 'Sept 23'),
#  ('July 23', 'Sept 23')]

# %%
list(combinations(names,2))
# Out:
# [('John', 'Mary'),
#  ('John', 'Rob'),
#  ('John', 'Susan'),
#  ('John', 'Violet'),
#  ('Mary', 'Rob'),
#  ('Mary', 'Susan'),
#  ('Mary', 'Violet'),
#  ('Rob', 'Susan'),
#  ('Rob', 'Violet'),
#  ('Susan', 'Violet')]

# %% [markdown]
# We can see how March 5th (John and Rob) are the same dates.Using Pandas

# %%
names_df = pd.DataFrame(combinations(names,2),columns = ['Person 1','Person 2'])
names_df
# Out:
#   Person 1 Person 2
# 0     John     Mary
# 1     John      Rob
# 2     John    Susan
# 3     John   Violet
# 4     Mary      Rob
# 5     Mary    Susan
# 6     Mary   Violet
# 7      Rob    Susan
# 8      Rob   Violet
# 9    Susan   Violet

# %%
birthday_df = pd.DataFrame(combinations(birthday,2),columns =['Birthday 1','Birthday 2'])
birthday_df
# Out:
#   Birthday 1 Birthday 2
# 0  March 5th  Sept 20th
# 1  March 5th   March 39
# 2  March 5th    July 23
# 3  March 5th    Sept 23
# 4  Sept 20th   March 39
# 5  Sept 20th    July 23
# 6  Sept 20th    Sept 23
# 7   March 39    July 23
# 8   March 39    Sept 23
# 9    July 23    Sept 23

# %% [markdown]
# combining it

# %%
df = pd.concat([names_df,birthday_df],axis = 1)
df
# Out:
#   Person 1 Person 2 Birthday 1 Birthday 2
# 0     John     Mary  March 5th  Sept 20th
# 1     John      Rob  March 5th   March 39
# 2     John    Susan  March 5th    July 23
# 3     John   Violet  March 5th    Sept 23
# 4     Mary      Rob  Sept 20th   March 39
# 5     Mary    Susan  Sept 20th    July 23
# 6     Mary   Violet  Sept 20th    Sept 23
# 7      Rob    Susan   March 39    July 23
# 8      Rob   Violet   March 39    Sept 23
# 9    Susan   Violet    July 23    Sept 23

# %%
df['Birthday 1'] == df['Birthday 2']
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %% [markdown]
# Activities

# %%
df= pd.read_csv('nba_players.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          Player    Ht     Wt     Colleges Pos  Age   Tm   G  GS  \
# 0           0  Alaa Abdelnaby  6-10  240.0         Duke  PF   22  POR  43   0
# 1           1     Danny Ainge   6-4  175.0          BYU  SG   31  POR  80   0
# 2           2     Mark Bryant   6-9  245.0   Seton Hall  PF   25  POR  53   0
# 3           3    Wayne Cooper  6-10  220.0  New Orleans   C   34  POR  67   1
# 4           4    Walter Davis   6-6  193.0          UNC  SG   36  POR  71  14
#
#    ...  Pts Max  Share                    Team   W   L   W/L%   GB   PS/G  \
# 0  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 1  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 2  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 3  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
# 4  ...      0.0    0.0  Portland Trail Blazers  63  19  0.768  0.0  114.7
#
#     PA/G   SRS
# 0  106.0  8.47
# 1  106.0  8.47
# ...

# %%
team_df = df.loc[df['Team'] == 'Atlanta Hawks']
team_df.head()
# Out:
#      Unnamed: 0               Player    Ht     Wt                   Colleges  \
# 491         491  Shareef Abdur-Rahim   6-9  225.0                 California
# 492         492          Cal Bowdler  6-10  245.0               Old Dominion
# 493         493       Chris Crawford   6-9  235.0                  Marquette
# 494         494        Emanual Davis   6-4  195.0  Delaware State University
# 495         495          Dion Glover   6-5  228.0               Georgia Tech
#
#     Pos  Age   Tm   G  GS  ...  Pts Max  Share           Team   W   L   W/L%  \
# 491  PF   25  ATL  77  77  ...      0.0    0.0  Atlanta Hawks  33  49  0.402
# 492  PF   24  ATL  52   0  ...      0.0    0.0  Atlanta Hawks  33  49  0.402
# 493  PF   26  ATL   7   4  ...      0.0    0.0  Atlanta Hawks  33  49  0.402
# 494  PG   33  ATL  28  20  ...      0.0    0.0  Atlanta Hawks  33  49  0.402
# 495  SG   23  ATL  55  25  ...      0.0    0.0  Atlanta Hawks  33  49  0.402
#
#        GB  PS/G  PA/G   SRS
# ...

# %%
team_df.shape
# Out:
# (653, 45)

# %%
names_df = pd.DataFrame(combinations(team_df['Player'],2),columns=['Players 1','players 2'])
names_df
# Out:
#                   Players 1       players 2
# 0       Shareef Abdur-Rahim     Cal Bowdler
# 1       Shareef Abdur-Rahim  Chris Crawford
# 2       Shareef Abdur-Rahim   Emanual Davis
# 3       Shareef Abdur-Rahim     Dion Glover
# 4       Shareef Abdur-Rahim  Alan Henderson
# ...                     ...             ...
# 212873          Jeff Teague    Jeremy Tyler
# 212874          Jeff Teague    Lou Williams
# 212875     Anthony Tolliver    Jeremy Tyler
# 212876     Anthony Tolliver    Lou Williams
# 212877         Jeremy Tyler    Lou Williams
#
# [212878 rows x 2 columns]

# %%
birthday_df = pd.DataFrame(combinations(team_df['Age'],2),columns = ['Age 1','Age 2'])
birthday_df
# Out:
#         Age 1  Age 2
# 0          25     24
# 1          25     26
# 2          25     33
# 3          25     23
# 4          25     29
# ...       ...    ...
# 212873     24     21
# 212874     24     26
# 212875     27     21
# 212876     27     26
# 212877     21     26
#
# [212878 rows x 2 columns]
